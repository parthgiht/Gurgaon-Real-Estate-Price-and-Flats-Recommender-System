# %%
import numpy as np
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv("appartments.csv").drop(22)

# %%
df.head()
# Out:
#                   PropertyName  \
# 0           Smartworld One DXP
# 1                    M3M Crown
# 2  Adani Brahma Samsara Vilasa
# 3                   Sobha City
# 4     Signature Global City 93
#
#                                      PropertySubName  \
# 0       2, 3, 4 BHK Apartment in Sector 113, Gurgaon
# 1          3, 4 BHK Apartment in Sector 111, Gurgaon
# 2  Land, 3, 4 BHK Independent Floor in Sector 63,...
# 3       2, 3, 4 BHK Apartment in Sector 108, Gurgaon
# 4    2, 3 BHK Independent Floor in Sector 93 Gurgaon
#
#                                      NearbyLocations  \
# 0  ['Bajghera Road', 'Palam Vihar Halt', 'DPSG Pa...
# 1  ['DPSG Palam Vihar Gurugram', 'The NorthCap Un...
# 2  ['AIPL Business Club Sector 62', 'Heritage Xpe...
# 3  ['The Shikshiyan School', 'WTC Plaza', 'Luxus ...
# 4  ['Pranavananda Int. School', 'DLF Site central...
#
#                                   LocationAdvantages  \
# 0  {'Bajghera Road': '800 Meter', 'Palam Vihar Ha...
# 1  {'DPSG Palam Vihar Gurugram': '1.4 Km', 'The N...
# 2  {'AIPL Business Club Sector 62': '2.7 Km', 'He...
# 3  {'The Shikshiyan School': '2.9 KM', 'WTC Plaza...
# 4  {'Pranavananda Int. School': '450 m', 'DLF Sit...
#
#                                                 Link  \
# 0  https://www.99acres.com/smartworld-one-dxp-sec...
# 1  https://www.99acres.com/m3m-crown-sector-111-g...
# 2  https://www.99acres.com/adani-brahma-samsara-v...
# 3  https://www.99acres.com/sobha-city-sector-108-...
# 4  https://www.99acres.com/signature-global-city-...
#
#                                         PriceDetails  \
# 0  {'2 BHK': {'building_type': 'Apartment', 'area...
# 1  {'3 BHK': {'building_type': 'Apartment', 'area...
# 2  {'3 BHK': {'building_type': 'Independent Floor...
# 3  {'2 BHK': {'building_type': 'Apartment', 'area...
# 4  {'2 BHK': {'building_type': 'Independent Floor...
#
#                                        TopFacilities
# 0  ['Swimming Pool', 'Salon', 'Restaurant', 'Spa'...
# 1  ['Bowling Alley', 'Mini Theatre', 'Manicured G...
# 2  ['Terrace Garden', 'Gazebo', 'Fountain', 'Amph...
# 3  ['Swimming Pool', 'Volley Ball Court', 'Aerobi...
# 4  ['Mini Theatre', 'Doctor on Call', 'Concierge ...

# %%
df.shape
# Out:
# (246, 7)

# %%
df.columns
# Out:
# Index(['PropertyName', 'PropertySubName', 'NearbyLocations',
#        'LocationAdvantages', 'Link', 'PriceDetails', 'TopFacilities'],
#       dtype='object')

# %%
df.iloc[1].NearbyLocations
# Out:
# "['DPSG Palam Vihar Gurugram', 'The NorthCap University', 'Park Hospital, Palam Vihar', 'Pacific D21 Mall', 'Palam Vihar Halt Railway Station']"

# %%
df.iloc[1].LocationAdvantages
# Out:
# "{'DPSG Palam Vihar Gurugram': '1.4 Km', 'The NorthCap University': '4.4 Km', 'Park Hospital, Palam Vihar': '1.4 Km', 'Pacific D21 Mall': '8.2 Km', 'Palam Vihar Halt Railway Station': '1.2 Km', 'Dwarka Sector 21 Metro Station': '8.1 Km', 'Dwarka Expressway': '450 m', 'Fun N Food Water Park': '8.1 Km', 'Indira Gandhi International Airport': '14.1 Km', 'Tau DeviLal Sports Complex': '11.2 Km', 'Hamoni Golf Camp': '5 Km', 'Hyatt Place': '6.1 Km', 'Altrade Business Centre': '11.2 Km'}"

# %%
df.iloc[1].PriceDetails
# Out:
# "{'3 BHK': {'building_type': 'Apartment', 'area_type': 'Super Built-up Area', 'area': '1,605 - 2,170 sq.ft.', 'price-range': '₹ 2.2 - 3.03 Cr'}, '4 BHK': {'building_type': 'Apartment', 'area_type': 'Super Built-up Area', 'area': '2,248 - 2,670 sq.ft.', 'price-range': '₹ 3.08 - 3.73 Cr'}}"

# %%
df.iloc[1].TopFacilities
# Out:
# "['Bowling Alley', 'Mini Theatre', 'Manicured Garden', 'Swimming Pool', 'Flower Garden', 'Reading Lounge', 'Golf Course', 'Barbecue', 'Sauna']"

# %% [markdown]
# # Top Facilities recommender system code

# %%
# Convert intno simple list
def extract_list(s):
    return re.findall(r"'(.*?)'",s)

df['TopFacilities'] = df['TopFacilities'].apply(extract_list)

# %%
df.head()
# Out:
#                   PropertyName  \
# 0           Smartworld One DXP
# 1                    M3M Crown
# 2  Adani Brahma Samsara Vilasa
# 3                   Sobha City
# 4     Signature Global City 93
#
#                                      PropertySubName  \
# 0       2, 3, 4 BHK Apartment in Sector 113, Gurgaon
# 1          3, 4 BHK Apartment in Sector 111, Gurgaon
# 2  Land, 3, 4 BHK Independent Floor in Sector 63,...
# 3       2, 3, 4 BHK Apartment in Sector 108, Gurgaon
# 4    2, 3 BHK Independent Floor in Sector 93 Gurgaon
#
#                                      NearbyLocations  \
# 0  ['Bajghera Road', 'Palam Vihar Halt', 'DPSG Pa...
# 1  ['DPSG Palam Vihar Gurugram', 'The NorthCap Un...
# 2  ['AIPL Business Club Sector 62', 'Heritage Xpe...
# 3  ['The Shikshiyan School', 'WTC Plaza', 'Luxus ...
# 4  ['Pranavananda Int. School', 'DLF Site central...
#
#                                   LocationAdvantages  \
# 0  {'Bajghera Road': '800 Meter', 'Palam Vihar Ha...
# 1  {'DPSG Palam Vihar Gurugram': '1.4 Km', 'The N...
# 2  {'AIPL Business Club Sector 62': '2.7 Km', 'He...
# 3  {'The Shikshiyan School': '2.9 KM', 'WTC Plaza...
# 4  {'Pranavananda Int. School': '450 m', 'DLF Sit...
#
#                                                 Link  \
# 0  https://www.99acres.com/smartworld-one-dxp-sec...
# 1  https://www.99acres.com/m3m-crown-sector-111-g...
# 2  https://www.99acres.com/adani-brahma-samsara-v...
# 3  https://www.99acres.com/sobha-city-sector-108-...
# 4  https://www.99acres.com/signature-global-city-...
#
#                                         PriceDetails  \
# 0  {'2 BHK': {'building_type': 'Apartment', 'area...
# 1  {'3 BHK': {'building_type': 'Apartment', 'area...
# 2  {'3 BHK': {'building_type': 'Independent Floor...
# 3  {'2 BHK': {'building_type': 'Apartment', 'area...
# 4  {'2 BHK': {'building_type': 'Independent Floor...
#
#                                        TopFacilities
# 0  [Swimming Pool, Salon, Restaurant, Spa, Cafete...
# 1  [Bowling Alley, Mini Theatre, Manicured Garden...
# 2  [Terrace Garden, Gazebo, Fountain, Amphitheatr...
# 3  [Swimming Pool, Volley Ball Court, Aerobics Ce...
# 4  [Mini Theatre, Doctor on Call, Concierge Servi...

# %%
# Convert list into string
df['FacilitiesStr'] = df['TopFacilities'].apply(' '.join)

# %%
df.head()
# Out:
#                   PropertyName  \
# 0           Smartworld One DXP
# 1                    M3M Crown
# 2  Adani Brahma Samsara Vilasa
# 3                   Sobha City
# 4     Signature Global City 93
#
#                                      PropertySubName  \
# 0       2, 3, 4 BHK Apartment in Sector 113, Gurgaon
# 1          3, 4 BHK Apartment in Sector 111, Gurgaon
# 2  Land, 3, 4 BHK Independent Floor in Sector 63,...
# 3       2, 3, 4 BHK Apartment in Sector 108, Gurgaon
# 4    2, 3 BHK Independent Floor in Sector 93 Gurgaon
#
#                                      NearbyLocations  \
# 0  ['Bajghera Road', 'Palam Vihar Halt', 'DPSG Pa...
# 1  ['DPSG Palam Vihar Gurugram', 'The NorthCap Un...
# 2  ['AIPL Business Club Sector 62', 'Heritage Xpe...
# 3  ['The Shikshiyan School', 'WTC Plaza', 'Luxus ...
# 4  ['Pranavananda Int. School', 'DLF Site central...
#
#                                   LocationAdvantages  \
# 0  {'Bajghera Road': '800 Meter', 'Palam Vihar Ha...
# 1  {'DPSG Palam Vihar Gurugram': '1.4 Km', 'The N...
# 2  {'AIPL Business Club Sector 62': '2.7 Km', 'He...
# 3  {'The Shikshiyan School': '2.9 KM', 'WTC Plaza...
# 4  {'Pranavananda Int. School': '450 m', 'DLF Sit...
#
#                                                 Link  \
# 0  https://www.99acres.com/smartworld-one-dxp-sec...
# 1  https://www.99acres.com/m3m-crown-sector-111-g...
# 2  https://www.99acres.com/adani-brahma-samsara-v...
# 3  https://www.99acres.com/sobha-city-sector-108-...
# 4  https://www.99acres.com/signature-global-city-...
#
#                                         PriceDetails  \
# 0  {'2 BHK': {'building_type': 'Apartment', 'area...
# 1  {'3 BHK': {'building_type': 'Apartment', 'area...
# 2  {'3 BHK': {'building_type': 'Independent Floor...
# 3  {'2 BHK': {'building_type': 'Apartment', 'area...
# 4  {'2 BHK': {'building_type': 'Independent Floor...
#
#                                        TopFacilities  \
# 0  [Swimming Pool, Salon, Restaurant, Spa, Cafete...
# 1  [Bowling Alley, Mini Theatre, Manicured Garden...
# 2  [Terrace Garden, Gazebo, Fountain, Amphitheatr...
# 3  [Swimming Pool, Volley Ball Court, Aerobics Ce...
# 4  [Mini Theatre, Doctor on Call, Concierge Servi...
#
#                                        FacilitiesStr
# 0  Swimming Pool Salon Restaurant Spa Cafeteria S...
# 1  Bowling Alley Mini Theatre Manicured Garden Sw...
# 2  Terrace Garden Gazebo Fountain Amphitheatre Pa...
# 3  Swimming Pool Volley Ball Court Aerobics Centr...
# 4  Mini Theatre Doctor on Call Concierge Service ...

# %% [markdown]
# #### TfidfVectorizer works to convert text data into numerical data so, that we can use input for machine learning algorithms

# %%
tfidf_vectorizer = TfidfVectorizer(stop_words = 'english', ngram_range = (1,2))

# %%
tfidf_matrix = tfidf_vectorizer.fit_transform(df['FacilitiesStr'])

# %%
tfidf_matrix.toarray().shape
# Out:
# (246, 953)

# %%
cosine_sim1 = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
cosine_sim1.shape
# Out:
# (246, 246)

# %%
cosine_sim1
# Out:
# array([[1.        , 0.01095159, 0.        , ..., 0.01183329, 0.08656385,
#         0.0110727 ],
#        [0.01095159, 1.        , 0.01982121, ..., 0.11904241, 0.01555534,
#         0.00963852],
#        [0.        , 0.01982121, 1.        , ..., 0.07020502, 0.03820314,
#         0.01962826],
#        ...,
#        [0.01183329, 0.11904241, 0.07020502, ..., 1.        , 0.09825738,
#         0.03255851],
#        [0.08656385, 0.01555534, 0.03820314, ..., 0.09825738, 1.        ,
#         0.06257614],
#        [0.0110727 , 0.00963852, 0.01962826, ..., 0.03255851, 0.06257614,
#         1.        ]])

# %%
def recommend_properties(property_name):

    # Get index of the property that matches the name
    idx = df.index[df['PropertyName'] == property_name].tolist()[0]

    # Get pairwise similarity scores with that property
    sim_scores = list(enumerate(cosine_sim1[idx]))

    # Sort the properties based on the similarity scores
    sim_scores = sorted(sim_scores, key = lambda x: x[1], reverse = True)

    # Get the scores of the 10 most similar properties 
    sim_scores = sim_scores[1:6]

    # Get the property indicies 
    property_indicies = [i[0] for i in sim_scores]

    recommendations_df = pd.DataFrame({
        'PropertyName' : df['PropertyName'].iloc[property_indicies],
        'SimilarityScore' : sim_scores
    })

    # Return the top 10 most similar properties 
    return recommendations_df

# %%
recommend_properties("DLF The Arbour")
# Out:
#            PropertyName            SimilarityScore
# 64      Ace Palm Floors   (63, 0.4529382062441955)
# 217         Yashika 104  (216, 0.4199606322926784)
# 93       JMS The Nation   (92, 0.4166584649363288)
# 154       India Rashtra   (153, 0.398954234680194)
# 0    Smartworld One DXP   (0, 0.38885046199432893)

# %% [markdown]
# # Price details recommender system code

# %%
import pandas as pd
import json

# Load dataset
appartments_df  = pd.read_csv('appartments.csv').drop(22)

# Function to parse and extract the required features from the PriceDetails column 
def refined_parse_modified(detail_str):
    try:
        details = json.loads(detail_str.replace("'", "\""))
    except:
        return {}

    extracted = {}
    for i, j in details.items():
        
        # Extract building type
        extracted[f'building type_{i}'] = j.get('building_type')

        # Parsing area details
        area = j.get('area', '')
        area_parts = area.split('-')
        if len(area_parts) == 1:
            try:
                value = float(area_parts[0].replace(',', '').replace(' sq.ft.', '').strip())
                extracted[f'area low {i}'] = value
                extracted[f'area high {i}'] = value
            except:
                extracted[f'area low {i}'] = None
                extracted[f'area high {i}'] = None
        elif len(area_parts) == 2:
            try:
                extracted[f'area low {i}'] = float(area_parts[0].replace(',', '').replace(' sq.ft.', '').strip())
                extracted[f'area high {i}'] = float(area_parts[1].replace(',', '').replace(' sq.ft.', '').strip())
            except:
                extracted[f'area low {i}'] = None
                extracted[f'area high {i}'] = None


        # Parsing price details
        price_range = j.get('price-range', '')
        price_parts = price_range.split('-')
        if len(price_parts) == 2:
            try:
                extracted[f'price low {i}'] = float(price_parts[0].replace('₹', '').replace(' Cr', '').replace(' L', '').strip())
                extracted[f'price high {i}'] = float(price_parts[1].replace('₹', '').replace(' Cr', '').replace(' L', '').strip())
                if 'L' in price_parts[0]:
                    extracted[f'price low {i}'] /= 100
                if 'L' in price_parts[1]:
                    extracted[f'price high {i}'] /= 100
            except:
                extracted[f'price low {i}'] = None
                extracted[f'price high {i}'] = None

    return extracted

# Apply the refined parsing and generate the new DataFrame structure 
data_refined = []

for _, row in appartments_df.iterrows():
    features = refined_parse_modified(row['PriceDetails'])

    # Construct a new row for the transformed dataframe 
    new_row = {'PropertyName' : row['PropertyName']}

    # Populate the new row with extracted features 
    for config in ['1 BHK', '2 BHK', '3 BHK', '4 BHK', '5 BHK', '6 BHK', '1 RK', 'Land']:
        new_row[f'building type_{config}'] = features.get(f'building type_{config}')
        new_row[f'area low {config}'] = features.get(f'area low {config}')
        new_row[f'area high {config}'] = features.get(f'area high {config}')
        new_row[f'price low {config}'] = features.get(f'price low {config}')
        new_row[f'price high {config}'] = features.get(f'price high {config}')
    data_refined.append(new_row)

df_final_refined_v2 = pd.DataFrame(data_refined).set_index('PropertyName')

# %%
df_final_refined_v2['building type_Land'] = df_final_refined_v2['building type_Land'].replace({'':'Land'})

# %%
df_final_refined_v2.columns
# Out:
# Index(['building type_1 BHK', 'area low 1 BHK', 'area high 1 BHK',
#        'price low 1 BHK', 'price high 1 BHK', 'building type_2 BHK',
#        'area low 2 BHK', 'area high 2 BHK', 'price low 2 BHK',
#        'price high 2 BHK', 'building type_3 BHK', 'area low 3 BHK',
#        'area high 3 BHK', 'price low 3 BHK', 'price high 3 BHK',
#        'building type_4 BHK', 'area low 4 BHK', 'area high 4 BHK',
#        'price low 4 BHK', 'price high 4 BHK', 'building type_5 BHK',
#        'area low 5 BHK', 'area high 5 BHK', 'price low 5 BHK',
#        'price high 5 BHK', 'building type_6 BHK', 'area low 6 BHK',
#        'area high 6 BHK', 'price low 6 BHK', 'price high 6 BHK',
#        'building type_1 RK', 'area low 1 RK', 'area high 1 RK',
#        'price low 1 RK', 'price high 1 RK', 'building type_Land',
#        'area low Land', 'area high Land', 'price low Land', 'price high Land'],
#       dtype='object')

# %%
categorical_columns = df_final_refined_v2.select_dtypes(include = ['object']).columns.tolist()

# %%
categorical_columns
# Out:
# ['building type_1 BHK',
#  'building type_2 BHK',
#  'building type_3 BHK',
#  'building type_4 BHK',
#  'building type_5 BHK',
#  'building type_6 BHK',
#  'building type_1 RK',
#  'building type_Land']

# %%
# Apply OneHot Encoding on categorical data 
OHE_df = pd.get_dummies(df_final_refined_v2, columns = categorical_columns, drop_first = True, dtype = int)

# %%
OHE_df.fillna(0, inplace = True)

# %%
OHE_df
# Out:
#                              area low 1 BHK  area high 1 BHK  price low 1 BHK  \
# PropertyName
# Smartworld One DXP                      0.0              0.0             0.00
# M3M Crown                               0.0              0.0             0.00
# Adani Brahma Samsara Vilasa             0.0              0.0             0.00
# Sobha City                              0.0              0.0             0.00
# Signature Global City 93                0.0              0.0             0.00
# ...                                     ...              ...              ...
# DLF Princeton Estate                    0.0              0.0             0.00
# Pyramid Urban Homes 2                 335.0            398.0            23.45
# Satya The Hermitage                     0.0              0.0             0.00
# BPTP Spacio                             0.0              0.0             0.00
# SS The Coralwood                        0.0              0.0             0.00
#
#                              price high 1 BHK  area low 2 BHK  \
# PropertyName
# Smartworld One DXP                     0.0000          1370.0
# M3M Crown                              0.0000             0.0
# Adani Brahma Samsara Vilasa            0.0000             0.0
# Sobha City                             0.0000          1381.0
# Signature Global City 93               0.0000           981.0
# ...                                       ...             ...
# DLF Princeton Estate                   0.0000           964.0
# Pyramid Urban Homes 2                  0.2786           500.0
# Satya The Hermitage                    0.0000          1450.0
# BPTP Spacio                            0.0000          1000.0
# SS The Coralwood                       0.0000          1320.0
#
#                              area high 2 BHK  price low 2 BHK  \
# PropertyName
# Smartworld One DXP                    1370.0           2.0000
# M3M Crown                                0.0           0.0000
# Adani Brahma Samsara Vilasa              0.0           0.0000
# Sobha City                            1692.0           1.5500
# Signature Global City 93              1118.0           0.9301
# ...                                      ...              ...
# DLF Princeton Estate                   964.0           0.0000
# Pyramid Urban Homes 2                  625.0           0.0000
# Satya The Hermitage                   1450.0           0.0000
# BPTP Spacio                           1079.0           0.0000
# SS The Coralwood                      1425.0           0.0000
#
#                              price high 2 BHK  area low 3 BHK  \
# PropertyName
# Smartworld One DXP                       2.40          1850.0
# M3M Crown                                0.00          1605.0
# Adani Brahma Samsara Vilasa              0.00          1800.0
# Sobha City                               3.21          1711.0
# Signature Global City 93                 1.06          1235.0
# ...                                       ...             ...
# DLF Princeton Estate                     0.00          1127.0
# Pyramid Urban Homes 2                    0.00             0.0
# Satya The Hermitage                      0.00          1991.0
# BPTP Spacio                              0.00          1225.0
# SS The Coralwood                         0.00          1750.0
#
#                              area high 3 BHK  ...  \
# PropertyName                                  ...
# Smartworld One DXP                    2050.0  ...
# M3M Crown                             2170.0  ...
# Adani Brahma Samsara Vilasa           3150.0  ...
# Sobha City                            2343.0  ...
# Signature Global City 93              1530.0  ...
# ...                                      ...  ...
# DLF Princeton Estate                  1127.0  ...
# Pyramid Urban Homes 2                    0.0  ...
# Satya The Hermitage                   1991.0  ...
# BPTP Spacio                           1865.0  ...
# SS The Coralwood                      1890.0  ...
#
#                              building type_2 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                               0
# M3M Crown                                                        0
# Adani Brahma Samsara Vilasa                                      0
# Sobha City                                                       0
# Signature Global City 93                                         1
# ...                                                            ...
# DLF Princeton Estate                                             0
# Pyramid Urban Homes 2                                            0
# Satya The Hermitage                                              0
# BPTP Spacio                                                      0
# SS The Coralwood                                                 0
#
#                              building type_2 BHK_Service Apartment  \
# PropertyName
# Smartworld One DXP                                               0
# M3M Crown                                                        0
# Adani Brahma Samsara Vilasa                                      0
# Sobha City                                                       0
# Signature Global City 93                                         0
# ...                                                            ...
# DLF Princeton Estate                                             0
# Pyramid Urban Homes 2                                            0
# Satya The Hermitage                                              0
# BPTP Spacio                                                      0
# SS The Coralwood                                                 0
#
#                              building type_3 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                               0
# M3M Crown                                                        0
# Adani Brahma Samsara Vilasa                                      1
# Sobha City                                                       0
# Signature Global City 93                                         1
# ...                                                            ...
# DLF Princeton Estate                                             0
# Pyramid Urban Homes 2                                            0
# Satya The Hermitage                                              0
# BPTP Spacio                                                      0
# SS The Coralwood                                                 0
#
#                              building type_3 BHK_Service Apartment  \
# PropertyName
# Smartworld One DXP                                               0
# M3M Crown                                                        0
# Adani Brahma Samsara Vilasa                                      0
# Sobha City                                                       0
# Signature Global City 93                                         0
# ...                                                            ...
# DLF Princeton Estate                                             0
# Pyramid Urban Homes 2                                            0
# Satya The Hermitage                                              0
# BPTP Spacio                                                      0
# SS The Coralwood                                                 0
#
#                              building type_3 BHK_Villa  \
# PropertyName
# Smartworld One DXP                                   0
# M3M Crown                                            0
# Adani Brahma Samsara Vilasa                          0
# Sobha City                                           0
# Signature Global City 93                             0
# ...                                                ...
# DLF Princeton Estate                                 0
# Pyramid Urban Homes 2                                0
# Satya The Hermitage                                  0
# BPTP Spacio                                          0
# SS The Coralwood                                     0
#
#                              building type_4 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                               0
# M3M Crown                                                        0
# Adani Brahma Samsara Vilasa                                      1
# Sobha City                                                       0
# Signature Global City 93                                         0
# ...                                                            ...
# DLF Princeton Estate                                             0
# Pyramid Urban Homes 2                                            0
# Satya The Hermitage                                              0
# BPTP Spacio                                                      0
# SS The Coralwood                                                 0
#
#                              building type_4 BHK_Villa  \
# PropertyName
# Smartworld One DXP                                   0
# M3M Crown                                            0
# Adani Brahma Samsara Vilasa                          0
# Sobha City                                           0
# Signature Global City 93                             0
# ...                                                ...
# DLF Princeton Estate                                 0
# Pyramid Urban Homes 2                                0
# Satya The Hermitage                                  0
# BPTP Spacio                                          0
# SS The Coralwood                                     0
#
#                              building type_5 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                               0
# M3M Crown                                                        0
# Adani Brahma Samsara Vilasa                                      0
# Sobha City                                                       0
# Signature Global City 93                                         0
# ...                                                            ...
# DLF Princeton Estate                                             0
# Pyramid Urban Homes 2                                            0
# Satya The Hermitage                                              0
# BPTP Spacio                                                      0
# SS The Coralwood                                                 0
#
#                              building type_5 BHK_Villa  \
# PropertyName
# Smartworld One DXP                                   0
# M3M Crown                                            0
# Adani Brahma Samsara Vilasa                          0
# Sobha City                                           0
# Signature Global City 93                             0
# ...                                                ...
# DLF Princeton Estate                                 0
# Pyramid Urban Homes 2                                0
# Satya The Hermitage                                  0
# BPTP Spacio                                          0
# SS The Coralwood                                     0
#
#                              building type_6 BHK_Villa
# PropertyName
# Smartworld One DXP                                   0
# M3M Crown                                            0
# Adani Brahma Samsara Vilasa                          0
# Sobha City                                           0
# Signature Global City 93                             0
# ...                                                ...
# DLF Princeton Estate                                 0
# Pyramid Urban Homes 2                                0
# Satya The Hermitage                                  0
# BPTP Spacio                                          0
# SS The Coralwood                                     0
#
# [246 rows x 43 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

OHE_df_normalized = pd.DataFrame(scaler.fit_transform(OHE_df), columns = OHE_df.columns, index = OHE_df.index)

# %%
OHE_df_normalized.head()
# Out:
#                              area low 1 BHK  area high 1 BHK  price low 1 BHK  \
# PropertyName
# Smartworld One DXP                -0.252266        -0.169584        -0.105197
# M3M Crown                         -0.252266        -0.169584        -0.105197
# Adani Brahma Samsara Vilasa       -0.252266        -0.169584        -0.105197
# Sobha City                        -0.252266        -0.169584        -0.105197
# Signature Global City 93          -0.252266        -0.169584        -0.105197
#
#                              price high 1 BHK  area low 2 BHK  \
# PropertyName
# Smartworld One DXP                  -0.082332        1.223499
# M3M Crown                           -0.082332       -0.893541
# Adani Brahma Samsara Vilasa         -0.082332       -0.893541
# Sobha City                          -0.082332        1.240497
# Signature Global City 93            -0.082332        0.622383
#
#                              area high 2 BHK  price low 2 BHK  \
# PropertyName
# Smartworld One DXP                  1.020101        -0.173712
# M3M Crown                          -0.896660        -0.283546
# Adani Brahma Samsara Vilasa        -0.896660        -0.283546
# Sobha City                          1.470610        -0.198425
# Signature Global City 93            0.667529        -0.232468
#
#                              price high 2 BHK  area low 3 BHK  \
# PropertyName
# Smartworld One DXP                   1.158423        0.553787
# M3M Crown                           -0.387986        0.293086
# Adani Brahma Samsara Vilasa         -0.387986        0.500583
# Sobha City                           1.680336        0.405879
# Signature Global City 93             0.295011       -0.100626
#
#                              area high 3 BHK  ...  \
# PropertyName                                  ...
# Smartworld One DXP                  0.370864  ...
# M3M Crown                           0.472749  ...
# Adani Brahma Samsara Vilasa         1.304803  ...
# Sobha City                          0.619632  ...
# Signature Global City 93           -0.070634  ...
#
#                              building type_2 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                       -0.289310
# M3M Crown                                                -0.289310
# Adani Brahma Samsara Vilasa                              -0.289310
# Sobha City                                               -0.289310
# Signature Global City 93                                  3.456497
#
#                              building type_2 BHK_Service Apartment  \
# PropertyName
# Smartworld One DXP                                       -0.063888
# M3M Crown                                                -0.063888
# Adani Brahma Samsara Vilasa                              -0.063888
# Sobha City                                               -0.063888
# Signature Global City 93                                 -0.063888
#
#                              building type_3 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                       -0.372678
# M3M Crown                                                -0.372678
# Adani Brahma Samsara Vilasa                               2.683282
# Sobha City                                               -0.372678
# Signature Global City 93                                  2.683282
#
#                              building type_3 BHK_Service Apartment  \
# PropertyName
# Smartworld One DXP                                       -0.063888
# M3M Crown                                                -0.063888
# Adani Brahma Samsara Vilasa                              -0.063888
# Sobha City                                               -0.063888
# Signature Global City 93                                 -0.063888
#
#                              building type_3 BHK_Villa  \
# PropertyName
# Smartworld One DXP                           -0.171139
# M3M Crown                                    -0.171139
# Adani Brahma Samsara Vilasa                  -0.171139
# Sobha City                                   -0.171139
# Signature Global City 93                     -0.171139
#
#                              building type_4 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                       -0.254824
# M3M Crown                                                -0.254824
# Adani Brahma Samsara Vilasa                               3.924283
# Sobha City                                               -0.254824
# Signature Global City 93                                 -0.254824
#
#                              building type_4 BHK_Villa  \
# PropertyName
# Smartworld One DXP                           -0.236208
# M3M Crown                                    -0.236208
# Adani Brahma Samsara Vilasa                  -0.236208
# Sobha City                                   -0.236208
# Signature Global City 93                     -0.236208
#
#                              building type_5 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                       -0.111111
# M3M Crown                                                -0.111111
# Adani Brahma Samsara Vilasa                              -0.111111
# Sobha City                                               -0.111111
# Signature Global City 93                                 -0.111111
#
#                              building type_5 BHK_Villa  \
# PropertyName
# Smartworld One DXP                           -0.216353
# M3M Crown                                    -0.216353
# Adani Brahma Samsara Vilasa                  -0.216353
# Sobha City                                   -0.216353
# Signature Global City 93                     -0.216353
#
#                              building type_6 BHK_Villa
# PropertyName
# Smartworld One DXP                           -0.063888
# M3M Crown                                    -0.063888
# Adani Brahma Samsara Vilasa                  -0.063888
# Sobha City                                   -0.063888
# Signature Global City 93                     -0.063888
#
# [5 rows x 43 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim2 = cosine_similarity(OHE_df_normalized)

# %%
cosine_sim2.shape
# Out:
# (246, 246)

# %%
def recommend_properties_with_scores(property_name, top_n = 247):

    # Get the similarity scores for the property using its name as the index
    sim_scores = list(enumerate(cosine_sim2[OHE_df_normalized.index.get_loc(property_name)]))

    # Sort properties based on the similarity scores
    sorted_scores = sorted(sim_scores, key = lambda x: x[1], reverse = True)

    # Get the indices and scores of thee top_n most similar properties 
    top_indices = [i[0] for i in sorted_scores[1: top_n + 1]]
    top_scores = [i[1] for i in sorted_scores[1: top_n + 1]]

    # Retrieve the names of the top properties using the indices 
    top_properties = OHE_df_normalized.index[top_indices].tolist()

    # Create a dataframe with the result 
    recommendations_df = pd.DataFrame({
        'PropertyName' : top_properties,
        'SimilarityScore' : top_scores
    })

    return recommendations_df


recommend_properties_with_scores('M3M Golf Hills')
# Out:
#                 PropertyName  SimilarityScore
# 0    AIPL The Peaceful Homes         0.955462
# 1         Smartworld One DXP         0.954670
# 2             Unitech Escape         0.953092
# 3                M3M Capital         0.951156
# 4                 BPTP Terra         0.943128
# ..                       ...              ...
# 240              Golden Park        -0.522391
# 241      Satya Merano Greens        -0.523660
# 242       ROF Normanton Park        -0.525129
# 243          BPTP Green Oaks        -0.525286
# 244           JMS The Nation        -0.526287
#
# [245 rows x 2 columns]

# %% [markdown]
# ## LocationAdvantage recommender system code

# %%
import pandas as pd
import ast
from fuzzywuzzy import fuzz
from sklearn.preprocessing import StandardScaler
# Out:
# D:\Anaconda3\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# Convert meter to kilometer 
def distance_to_meter(distance_str):
    try:
        if 'Km' in distance_str or 'KM' in distance_str:
            return float(distance_str.split()[0]) * 1000
        elif 'Meter' in distance_str or 'meter' in distance_str:
            return float(distance_str.split()[0])
        else:
            return None

    except:
        return None

# %%
# Define a mapping for standardizing location names
location_mapping = {
    'Dwarka Expy': 'Dwarka Expressway',
    'Dwarka Express Way': 'Dwarka Expressway',
    'Northern Peripheral Road': 'Dwarka Expressway',
    'Indira Gandhi Intl Airport': 'IGI Airport',
    'Indira Gandhi International Airport': 'IGI Airport',
    'Delhi International Airport': 'IGI Airport',
    'Golf Course Ext Rd': 'Golf Course Extension Road',
    'Golf Course Ext Road': 'Golf Course Extension Road',
    'Badshahpur Sohna Rd Hwy': 'Sohna Road',
    'Sohna Rd': 'Sohna Road',
    'NH 48': 'Delhi Jaipur Expressway',
    'Delhi - Jaipur Expressway': 'Delhi Jaipur Expressway',
    'NH8': 'Delhi Jaipur Expressway',
    'Gurgaon Railway Station': 'Gurugram Railway Station',
    'Sector 55-56 Metro Station': 'Sector 55-56 Metro Station',
    'Sector 55/56 Metro Station': 'Sector 55-56 Metro Station',
    'Pacific D21 Mall': 'Pacific D21 Mall',
    'Pacific Outlet Mall': 'Pacific D21 Mall',
    'The NorthCap University': 'NorthCap University',
    'Northcap University': 'NorthCap University',
}

# %%
# Function to standardize location names
def standardize_location_name(location, mapping, threshold=85):
    if location in mapping:
        return mapping[location]
    # Fuzzy match to find the closest standardized name
    for standard_name, mapped_name in mapping.items():
        if fuzz.ratio(location.lower(), standard_name.lower()) > threshold:
            return mapped_name
    return location

# %%
# Collect all unique location names 
all_locations = set()
for index, row in df.iterrows():
    location_dict = ast.literal_eval(row['LocationAdvantages'])
    all_locations.update(location_dict.keys())

# %%
# Extract distance for each location with standardized names
location_matrix = {}
for index, row in df.iterrows():
    distances = {}
    location_dict = ast.literal_eval(row['LocationAdvantages'])
    for location, distance in location_dict.items():
        standardized_location = standardize_location_name(location, location_mapping)
        distances[standardized_location] = distance_to_meter(distance)
    location_matrix[index] = distances


# Convert dictionary to DataFrame
location_df = pd.DataFrame.from_dict(location_matrix, orient='index')

# %%
location_df.index = df.PropertyName

# %%
# Fill NaN values with the maximum value for each column
location_df.fillna(25440, inplace = True)

# %%
# Replace 25440.0  with random values between 1000m and 25000m
def fill_random_distances(val):
    if val == 25440.0:
        return np.round(np.random.uniform(10550, 25000), 1)
    return val

# Apply to entire DataFrame (excluding index)
location_df = location_df.applymap(fill_random_distances)
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_2160\4005752115.py:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   location_df = location_df.applymap(fill_random_distances)

# %%
location_df
# Out:
#                              Bajghera Road  Palam Vihar Halt  \
# PropertyName
# Smartworld One DXP                   800.0            2500.0
# M3M Crown                            550.0           11466.2
# Adani Brahma Samsara Vilasa         5300.0           20602.8
# Sobha City                          1500.0           19546.3
# Signature Global City 93           19518.1           22592.3
# ...                                    ...               ...
# DLF Princeton Estate               13615.6           22885.8
# Pyramid Urban Homes 2              16809.3           13027.5
# Satya The Hermitage                18521.8           24813.7
# BPTP Spacio                        24813.9           12174.0
# SS The Coralwood                   24027.6           17614.5
#
#                              DPSG Palam Vihar  Park Hospital  \
# PropertyName
# Smartworld One DXP                     3100.0         3100.0
# M3M Crown                             14937.4        17890.0
# Adani Brahma Samsara Vilasa           15061.7        24005.0
# Sobha City                            23675.3        13116.7
# Signature Global City 93              14020.1         5500.0
# ...                                       ...            ...
# DLF Princeton Estate                  18597.0        22304.2
# Pyramid Urban Homes 2                 18382.7        11988.3
# Satya The Hermitage                   13207.5        20318.8
# BPTP Spacio                           11894.7        15020.5
# SS The Coralwood                      19148.6        21484.6
#
#                              Gurugram Railway Station  NorthCap University  \
# PropertyName
# Smartworld One DXP                             4900.0               5400.0
# M3M Crown                                     21305.9               6700.0
# Adani Brahma Samsara Vilasa                    2500.0               8800.0
# Sobha City                                     6500.0               6700.0
# Signature Global City 93                      18842.3              15382.2
# ...                                               ...                  ...
# DLF Princeton Estate                          15808.7              16684.5
# Pyramid Urban Homes 2                         18679.9              20906.1
# Satya The Hermitage                           16629.9              14379.7
# BPTP Spacio                                   10564.2              21493.3
# SS The Coralwood                              22553.9              13526.3
#
#                              Dwarka Expressway  \
# PropertyName
# Smartworld One DXP                      1200.0
# M3M Crown                               3800.0
# Adani Brahma Samsara Vilasa              700.0
# Sobha City                              5100.0
# Signature Global City 93               20437.9
# ...                                        ...
# DLF Princeton Estate                   16271.3
# Pyramid Urban Homes 2                  21792.6
# Satya The Hermitage                    17090.2
# BPTP Spacio                            17376.8
# SS The Coralwood                       15784.7
#
#                              Hyatt Place Gurgaon Udyog Vihar  \
# PropertyName
# Smartworld One DXP                                    7700.0
# M3M Crown                                            15396.7
# Adani Brahma Samsara Vilasa                          22365.5
# Sobha City                                           15219.0
# Signature Global City 93                             18704.2
# ...                                                      ...
# DLF Princeton Estate                                 11181.7
# Pyramid Urban Homes 2                                16458.9
# Satya The Hermitage                                  15693.2
# BPTP Spacio                                          15968.9
# SS The Coralwood                                     10898.0
#
#                              Dwarka Sector 21, Metro Station  \
# PropertyName
# Smartworld One DXP                                    7200.0
# M3M Crown                                            15624.3
# Adani Brahma Samsara Vilasa                          12090.8
# Sobha City                                           18910.0
# Signature Global City 93                             12395.1
# ...                                                      ...
# DLF Princeton Estate                                 21284.7
# Pyramid Urban Homes 2                                23489.4
# Satya The Hermitage                                  14598.7
# BPTP Spacio                                          15541.1
# SS The Coralwood                                     15688.8
#
#                              Pacific D21 Mall  ...  \
# PropertyName                                   ...
# Smartworld One DXP                     7400.0  ...
# M3M Crown                              7500.0  ...
# Adani Brahma Samsara Vilasa           12437.5  ...
# Sobha City                             8200.0  ...
# Signature Global City 93              19485.9  ...
# ...                                       ...  ...
# DLF Princeton Estate                  20480.8  ...
# Pyramid Urban Homes 2                 13501.1  ...
# Satya The Hermitage                   15873.0  ...
# BPTP Spacio                           23039.1  ...
# SS The Coralwood                      19402.8  ...
#
#                              MCC Cricket Ground Dhankot  \
# PropertyName
# Smartworld One DXP                              20427.1
# M3M Crown                                       18173.5
# Adani Brahma Samsara Vilasa                     15360.8
# Sobha City                                      22363.6
# Signature Global City 93                        11572.7
# ...                                                 ...
# DLF Princeton Estate                            11227.2
# Pyramid Urban Homes 2                           10766.4
# Satya The Hermitage                             17047.3
# BPTP Spacio                                     12993.7
# SS The Coralwood                                15809.0
#
#                              The Shri Ram School Aravali  \
# PropertyName
# Smartworld One DXP                               24488.6
# M3M Crown                                        16092.7
# Adani Brahma Samsara Vilasa                      12780.9
# Sobha City                                       22075.7
# Signature Global City 93                         15632.3
# ...                                                  ...
# DLF Princeton Estate                             20559.2
# Pyramid Urban Homes 2                            14543.2
# Satya The Hermitage                              19595.4
# BPTP Spacio                                      11213.7
# SS The Coralwood                                 22389.3
#
#                              Taj City Centre Gurugram  \
# PropertyName
# Smartworld One DXP                            18621.0
# M3M Crown                                     22228.6
# Adani Brahma Samsara Vilasa                   12449.1
# Sobha City                                    20559.6
# Signature Global City 93                      16347.2
# ...                                               ...
# DLF Princeton Estate                          15721.4
# Pyramid Urban Homes 2                         12967.5
# Satya The Hermitage                           16282.8
# BPTP Spacio                                   14417.1
# SS The Coralwood                              14376.6
#
#                              Minda Industries  Corporate Office  \
# PropertyName
# Smartworld One DXP                                      12666.4
# M3M Crown                                               24974.4
# Adani Brahma Samsara Vilasa                             11501.1
# Sobha City                                              24159.0
# Signature Global City 93                                13602.1
# ...                                                         ...
# DLF Princeton Estate                                    22449.8
# Pyramid Urban Homes 2                                   21107.4
# Satya The Hermitage                                     13720.1
# BPTP Spacio                                             13693.5
# SS The Coralwood                                        20691.5
#
#                              Rampura Flyover, Naurangpur Rd  \
# PropertyName
# Smartworld One DXP                                  11022.5
# M3M Crown                                           19464.7
# Adani Brahma Samsara Vilasa                         13535.0
# Sobha City                                          11287.1
# Signature Global City 93                            16979.2
# ...                                                     ...
# DLF Princeton Estate                                20709.5
# Pyramid Urban Homes 2                               23707.6
# Satya The Hermitage                                 15384.7
# BPTP Spacio                                         23284.9
# SS The Coralwood                                    19529.8
#
#                              Manesar toll plaza - Kherki Daula  \
# PropertyName
# Smartworld One DXP                                     16540.4
# M3M Crown                                              21413.3
# Adani Brahma Samsara Vilasa                            14440.7
# Sobha City                                             19151.0
# Signature Global City 93                               20541.7
# ...                                                        ...
# DLF Princeton Estate                                   13068.4
# Pyramid Urban Homes 2                                  17524.5
# Satya The Hermitage                                    13568.7
# BPTP Spacio                                            15645.7
# SS The Coralwood                                       18640.3
#
#                              Imt Manesar, Gurugram  Holiday Inn  \
# PropertyName
# Smartworld One DXP                         16180.0      23952.2
# M3M Crown                                  11373.2      17748.4
# Adani Brahma Samsara Vilasa                12876.0      17965.1
# Sobha City                                 15260.4      10905.6
# Signature Global City 93                   23499.4      14364.7
# ...                                            ...          ...
# DLF Princeton Estate                       19832.2      20912.5
# Pyramid Urban Homes 2                      21098.3      12490.2
# Satya The Hermitage                        20813.2      16095.2
# BPTP Spacio                                22097.5      18715.8
# SS The Coralwood                           11831.7      20530.5
#
#                              Sector 84 Road  Skyview Corporate Park
# PropertyName
# Smartworld One DXP                  19266.1                 11990.1
# M3M Crown                           17047.5                 13214.4
# Adani Brahma Samsara Vilasa         14864.0                 23246.8
# Sobha City                          23123.4                 19731.1
# Signature Global City 93            16724.4                 23316.0
# ...                                     ...                     ...
# DLF Princeton Estate                23829.8                 13621.4
# Pyramid Urban Homes 2               15960.1                 12690.9
# Satya The Hermitage                 23391.8                 20531.1
# BPTP Spacio                         21732.2                 21578.9
# SS The Coralwood                    15688.8                 20683.3
#
# [246 rows x 1027 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

location_df_normalized = pd.DataFrame(scaler.fit_transform(location_df), columns = location_df.columns, index = location_df.index)

# %%
location_df_normalized.head()
# Out:
#                              Bajghera Road  Palam Vihar Halt  \
# PropertyName
# Smartworld One DXP               -3.702162         -3.490526
# M3M Crown                        -3.756371         -1.430131
# Adani Brahma Samsara Vilasa      -2.726406          0.669421
# Sobha City                       -3.550378          0.426642
# Signature Global City 93          0.356572          1.126600
#
#                              DPSG Palam Vihar  Park Hospital  \
# PropertyName
# Smartworld One DXP                  -3.346868      -2.425671
# M3M Crown                           -0.654992       0.229898
# Adani Brahma Samsara Vilasa         -0.626726       1.327856
# Sobha City                           1.332044      -0.627156
# Signature Global City 93            -0.863590      -1.994747
#
#                              Gurugram Railway Station  NorthCap University  \
# PropertyName
# Smartworld One DXP                          -2.156429            -2.281414
# M3M Crown                                    0.882727            -2.022801
# Adani Brahma Samsara Vilasa                 -2.601023            -1.605041
# Sobha City                                  -1.860032            -2.022801
# Signature Global City 93                     0.426351            -0.295622
#
#                              Dwarka Expressway  \
# PropertyName
# Smartworld One DXP                   -1.707223
# M3M Crown                            -1.358371
# Adani Brahma Samsara Vilasa          -1.774310
# Sobha City                           -1.183945
# Signature Global City 93              0.874000
#
#                              Hyatt Place Gurgaon Udyog Vihar  \
# PropertyName
# Smartworld One DXP                                 -2.160322
# M3M Crown                                          -0.456049
# Adani Brahma Samsara Vilasa                         1.087047
# Sobha City                                         -0.495396
# Signature Global City 93                            0.276328
#
#                              Dwarka Sector 21, Metro Station  \
# PropertyName
# Smartworld One DXP                                 -2.423080
# M3M Crown                                          -0.475594
# Adani Brahma Samsara Vilasa                        -1.292450
# Sobha City                                          0.283977
# Signature Global City 93                           -1.222104
#
#                              Pacific D21 Mall  ...  \
# PropertyName                                   ...
# Smartworld One DXP                  -2.390939  ...
# M3M Crown                           -2.367406  ...
# Adani Brahma Samsara Vilasa         -1.205496  ...
# Sobha City                          -2.202680  ...
# Signature Global City 93             0.453158  ...
#
#                              MCC Cricket Ground Dhankot  \
# PropertyName
# Smartworld One DXP                             0.605222
# M3M Crown                                      0.057257
# Adani Brahma Samsara Vilasa                   -0.626653
# Sobha City                                     1.076084
# Signature Global City 93                      -1.547733
#
#                              The Shri Ram School Aravali  \
# PropertyName
# Smartworld One DXP                              1.517591
# M3M Crown                                      -0.376492
# Adani Brahma Samsara Vilasa                    -1.123622
# Sobha City                                      0.973250
# Signature Global City 93                       -0.480357
#
#                              Taj City Centre Gurugram  \
# PropertyName
# Smartworld One DXP                           0.233413
# M3M Crown                                    1.112700
# Adani Brahma Samsara Vilasa                 -1.270876
# Sobha City                                   0.705911
# Signature Global City 93                    -0.320785
#
#                              Minda Industries  Corporate Office  \
# PropertyName
# Smartworld One DXP                                    -1.186159
# M3M Crown                                              1.642631
# Adani Brahma Samsara Vilasa                           -1.453984
# Sobha City                                             1.455225
# Signature Global City 93                              -0.971104
#
#                              Rampura Flyover, Naurangpur Rd  \
# PropertyName
# Smartworld One DXP                                -1.624721
# M3M Crown                                          0.388239
# Adani Brahma Samsara Vilasa                       -1.025640
# Sobha City                                        -1.561630
# Signature Global City 93                          -0.204404
#
#                              Manesar toll plaza - Kherki Daula  \
# PropertyName
# Smartworld One DXP                                   -0.275760
# M3M Crown                                             0.858898
# Adani Brahma Samsara Vilasa                          -0.764677
# Sobha City                                            0.332120
# Signature Global City 93                              0.655946
#
#                              Imt Manesar, Gurugram  Holiday Inn  \
# PropertyName
# Smartworld One DXP                       -0.348400     1.551910
# M3M Crown                                -1.491441     0.012468
# Adani Brahma Samsara Vilasa              -1.134080     0.066241
# Sobha City                               -0.567078    -1.685539
# Signature Global City 93                  1.392130    -0.827181
#
#                              Sector 84 Road  Skyview Corporate Park
# PropertyName
# Smartworld One DXP                 0.258513               -1.379573
# M3M Crown                         -0.240288               -1.092189
# Adani Brahma Samsara Vilasa       -0.731196                1.262752
# Sobha City                         1.125736                0.437499
# Signature Global City 93          -0.312929                1.278996
#
# [5 rows x 1027 columns]

# %%
cosine_sim3 = cosine_similarity(location_df_normalized)

# %%
cosine_sim3.shape
# Out:
# (246, 246)

# %%
def recommend_properties_with_scores(property_name, top_n = 247):

    cosine_sim_matrix = 0.5 * cosine_sim1 + 0.8 * cosine_sim2 + 1 * cosine_sim3
    
    # Get the similarity scores for the property using its name as the index
    sim_scores = list(enumerate(cosine_sim_matrix[location_df_normalized.index.get_loc(property_name)]))

    # Sort properties based on the similarity scores
    sorted_scores = sorted(sim_scores, key = lambda x: x[1], reverse = True)

    # Get the indices and scores of thee top_n most similar properties 
    top_indices = [i[0] for i in sorted_scores[1: top_n + 1]]
    top_scores = [i[1] for i in sorted_scores[1: top_n + 1]]

    # Retrieve the names of the top properties using the indices 
    top_properties = location_df_normalized.index[top_indices].tolist()

    # Create a dataframe with the result 
    recommendations_df = pd.DataFrame({
        'PropertyName' : top_properties,
        'SimilarityScore' : top_scores
    })

    return recommendations_df


recommend_properties_with_scores('DLF The Camellias')
# Out:
#                     PropertyName  SimilarityScore
# 0            Salcon The Verandas         0.821292
# 1              DLF The Magnolias         0.613285
# 2                DLF The Aralias         0.498701
# 3              Parsvnath Exotica         0.435815
# 4         Pioneer Urban Presidia         0.343247
# ..                           ...              ...
# 240         DLF Princeton Estate        -0.290171
# 241                  M3M Skycity        -0.292590
# 242                M3M Sierra 68        -0.293934
# 243  Godrej Nature Plus Serenity        -0.315705
# 244     Emaar MGF Emerald Estate        -0.326748
#
# [245 rows x 2 columns]

# %%
x = location_df[location_df['Bajghera Road'] < 2000]['Bajghera Road'].sort_values().to_dict()
for key, value in x.items():
    print(key,value)
# Out:
# M3M Crown 550.0
# Smartworld One DXP 800.0
# Sobha City 1500.0

# %%
import pickle 

# pickle.dump(location_df, open('location_distance.pkl','wb'))
pickle.dump(cosine_sim1, open('cosine_sim1.pkl','wb'))
pickle.dump(cosine_sim2, open('cosine_sim2.pkl','wb'))
pickle.dump(cosine_sim3, open('cosine_sim3.pkl','wb'))

# %%
location_df
# Out:
#                              Bajghera Road  Palam Vihar Halt  \
# PropertyName
# Smartworld One DXP                   800.0            2500.0
# M3M Crown                            550.0           11466.2
# Adani Brahma Samsara Vilasa         5300.0           20602.8
# Sobha City                          1500.0           19546.3
# Signature Global City 93           19518.1           22592.3
# ...                                    ...               ...
# DLF Princeton Estate               13615.6           22885.8
# Pyramid Urban Homes 2              16809.3           13027.5
# Satya The Hermitage                18521.8           24813.7
# BPTP Spacio                        24813.9           12174.0
# SS The Coralwood                   24027.6           17614.5
#
#                              DPSG Palam Vihar  Park Hospital  \
# PropertyName
# Smartworld One DXP                     3100.0         3100.0
# M3M Crown                             14937.4        17890.0
# Adani Brahma Samsara Vilasa           15061.7        24005.0
# Sobha City                            23675.3        13116.7
# Signature Global City 93              14020.1         5500.0
# ...                                       ...            ...
# DLF Princeton Estate                  18597.0        22304.2
# Pyramid Urban Homes 2                 18382.7        11988.3
# Satya The Hermitage                   13207.5        20318.8
# BPTP Spacio                           11894.7        15020.5
# SS The Coralwood                      19148.6        21484.6
#
#                              Gurugram Railway Station  NorthCap University  \
# PropertyName
# Smartworld One DXP                             4900.0               5400.0
# M3M Crown                                     21305.9               6700.0
# Adani Brahma Samsara Vilasa                    2500.0               8800.0
# Sobha City                                     6500.0               6700.0
# Signature Global City 93                      18842.3              15382.2
# ...                                               ...                  ...
# DLF Princeton Estate                          15808.7              16684.5
# Pyramid Urban Homes 2                         18679.9              20906.1
# Satya The Hermitage                           16629.9              14379.7
# BPTP Spacio                                   10564.2              21493.3
# SS The Coralwood                              22553.9              13526.3
#
#                              Dwarka Expressway  \
# PropertyName
# Smartworld One DXP                      1200.0
# M3M Crown                               3800.0
# Adani Brahma Samsara Vilasa              700.0
# Sobha City                              5100.0
# Signature Global City 93               20437.9
# ...                                        ...
# DLF Princeton Estate                   16271.3
# Pyramid Urban Homes 2                  21792.6
# Satya The Hermitage                    17090.2
# BPTP Spacio                            17376.8
# SS The Coralwood                       15784.7
#
#                              Hyatt Place Gurgaon Udyog Vihar  \
# PropertyName
# Smartworld One DXP                                    7700.0
# M3M Crown                                            15396.7
# Adani Brahma Samsara Vilasa                          22365.5
# Sobha City                                           15219.0
# Signature Global City 93                             18704.2
# ...                                                      ...
# DLF Princeton Estate                                 11181.7
# Pyramid Urban Homes 2                                16458.9
# Satya The Hermitage                                  15693.2
# BPTP Spacio                                          15968.9
# SS The Coralwood                                     10898.0
#
#                              Dwarka Sector 21, Metro Station  \
# PropertyName
# Smartworld One DXP                                    7200.0
# M3M Crown                                            15624.3
# Adani Brahma Samsara Vilasa                          12090.8
# Sobha City                                           18910.0
# Signature Global City 93                             12395.1
# ...                                                      ...
# DLF Princeton Estate                                 21284.7
# Pyramid Urban Homes 2                                23489.4
# Satya The Hermitage                                  14598.7
# BPTP Spacio                                          15541.1
# SS The Coralwood                                     15688.8
#
#                              Pacific D21 Mall  ...  \
# PropertyName                                   ...
# Smartworld One DXP                     7400.0  ...
# M3M Crown                              7500.0  ...
# Adani Brahma Samsara Vilasa           12437.5  ...
# Sobha City                             8200.0  ...
# Signature Global City 93              19485.9  ...
# ...                                       ...  ...
# DLF Princeton Estate                  20480.8  ...
# Pyramid Urban Homes 2                 13501.1  ...
# Satya The Hermitage                   15873.0  ...
# BPTP Spacio                           23039.1  ...
# SS The Coralwood                      19402.8  ...
#
#                              MCC Cricket Ground Dhankot  \
# PropertyName
# Smartworld One DXP                              20427.1
# M3M Crown                                       18173.5
# Adani Brahma Samsara Vilasa                     15360.8
# Sobha City                                      22363.6
# Signature Global City 93                        11572.7
# ...                                                 ...
# DLF Princeton Estate                            11227.2
# Pyramid Urban Homes 2                           10766.4
# Satya The Hermitage                             17047.3
# BPTP Spacio                                     12993.7
# SS The Coralwood                                15809.0
#
#                              The Shri Ram School Aravali  \
# PropertyName
# Smartworld One DXP                               24488.6
# M3M Crown                                        16092.7
# Adani Brahma Samsara Vilasa                      12780.9
# Sobha City                                       22075.7
# Signature Global City 93                         15632.3
# ...                                                  ...
# DLF Princeton Estate                             20559.2
# Pyramid Urban Homes 2                            14543.2
# Satya The Hermitage                              19595.4
# BPTP Spacio                                      11213.7
# SS The Coralwood                                 22389.3
#
#                              Taj City Centre Gurugram  \
# PropertyName
# Smartworld One DXP                            18621.0
# M3M Crown                                     22228.6
# Adani Brahma Samsara Vilasa                   12449.1
# Sobha City                                    20559.6
# Signature Global City 93                      16347.2
# ...                                               ...
# DLF Princeton Estate                          15721.4
# Pyramid Urban Homes 2                         12967.5
# Satya The Hermitage                           16282.8
# BPTP Spacio                                   14417.1
# SS The Coralwood                              14376.6
#
#                              Minda Industries  Corporate Office  \
# PropertyName
# Smartworld One DXP                                      12666.4
# M3M Crown                                               24974.4
# Adani Brahma Samsara Vilasa                             11501.1
# Sobha City                                              24159.0
# Signature Global City 93                                13602.1
# ...                                                         ...
# DLF Princeton Estate                                    22449.8
# Pyramid Urban Homes 2                                   21107.4
# Satya The Hermitage                                     13720.1
# BPTP Spacio                                             13693.5
# SS The Coralwood                                        20691.5
#
#                              Rampura Flyover, Naurangpur Rd  \
# PropertyName
# Smartworld One DXP                                  11022.5
# M3M Crown                                           19464.7
# Adani Brahma Samsara Vilasa                         13535.0
# Sobha City                                          11287.1
# Signature Global City 93                            16979.2
# ...                                                     ...
# DLF Princeton Estate                                20709.5
# Pyramid Urban Homes 2                               23707.6
# Satya The Hermitage                                 15384.7
# BPTP Spacio                                         23284.9
# SS The Coralwood                                    19529.8
#
#                              Manesar toll plaza - Kherki Daula  \
# PropertyName
# Smartworld One DXP                                     16540.4
# M3M Crown                                              21413.3
# Adani Brahma Samsara Vilasa                            14440.7
# Sobha City                                             19151.0
# Signature Global City 93                               20541.7
# ...                                                        ...
# DLF Princeton Estate                                   13068.4
# Pyramid Urban Homes 2                                  17524.5
# Satya The Hermitage                                    13568.7
# BPTP Spacio                                            15645.7
# SS The Coralwood                                       18640.3
#
#                              Imt Manesar, Gurugram  Holiday Inn  \
# PropertyName
# Smartworld One DXP                         16180.0      23952.2
# M3M Crown                                  11373.2      17748.4
# Adani Brahma Samsara Vilasa                12876.0      17965.1
# Sobha City                                 15260.4      10905.6
# Signature Global City 93                   23499.4      14364.7
# ...                                            ...          ...
# DLF Princeton Estate                       19832.2      20912.5
# Pyramid Urban Homes 2                      21098.3      12490.2
# Satya The Hermitage                        20813.2      16095.2
# BPTP Spacio                                22097.5      18715.8
# SS The Coralwood                           11831.7      20530.5
#
#                              Sector 84 Road  Skyview Corporate Park
# PropertyName
# Smartworld One DXP                  19266.1                 11990.1
# M3M Crown                           17047.5                 13214.4
# Adani Brahma Samsara Vilasa         14864.0                 23246.8
# Sobha City                          23123.4                 19731.1
# Signature Global City 93            16724.4                 23316.0
# ...                                     ...                     ...
# DLF Princeton Estate                23829.8                 13621.4
# Pyramid Urban Homes 2               15960.1                 12690.9
# Satya The Hermitage                 23391.8                 20531.1
# BPTP Spacio                         21732.2                 21578.9
# SS The Coralwood                    15688.8                 20683.3
#
# [246 rows x 1027 columns]
