# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Final1_gurgaon_properties_cleaned.csv')
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 2          flat                pyramid elite   sector 86   0.46
# 3          flat       breez global hill view  sohna road   0.32
# 4          flat  bestech park view sanskruti   sector 92   1.60
#
#    price_per_sqft     area                                       areaWithType  \
# 0          7585.0   1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8600.0   1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 2            79.0  58228.0                 Carpet area: 58141 (5401.48 sq.m.)
# 3          5470.0    585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 4          8020.0   1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
#
#    bedRoom  bathroom balcony  ...  super_built_up_area built_up_area  \
# 0        3         2       2  ...               1081.0           NaN
# 1        2         2       2  ...                  NaN           NaN
# 2        2         2       1  ...                  NaN           NaN
# 3        2         2       1  ...                  NaN        1000.0
# 4        3         4      3+  ...               1995.0        1615.0
#
#   carpet_area  study room  servant room  store room  pooja room  others room  \
# 0       650.0           0             0           0           0            0
# 1      1103.0           1             1           0           0            0
# 2     58141.0           0             0           0           0            0
# 3       585.0           0             0           0           0            0
# 4      1476.0           0             1           0           0            0
#
#    furnishing_type  luxury_score
# 0                1             8
# 1                1            38
# 2                1            15
# 3                1            49
# 4                2           174
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (3803, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3803 entries, 0 to 3802
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_type        3803 non-null   object
#  1   society              3802 non-null   object
#  2   sector               3803 non-null   object
#  3   price                3785 non-null   float64
#  4   price_per_sqft       3785 non-null   float64
#  5   area                 3785 non-null   float64
#  6   areaWithType         3803 non-null   object
#  7   bedRoom              3803 non-null   int64
#  8   bathroom             3803 non-null   int64
#  9   balcony              3803 non-null   object
#  10  floorNum             3784 non-null   float64
#  11  facing               2698 non-null   object
#  12  agePossession        3803 non-null   object
#  13  super_built_up_area  1915 non-null   float64
#  14  built_up_area        1187 non-null   float64
#  15  carpet_area          1944 non-null   float64
#  16  study room           3803 non-null   int64
#  17  servant room         3803 non-null   int64
#  18  store room           3803 non-null   int64
#  19  pooja room           3803 non-null   int64
#  20  others room          3803 non-null   int64
#  21  furnishing_type      3803 non-null   int64
#  22  luxury_score         3803 non-null   int64
# dtypes: float64(7), int64(9), object(7)
# memory usage: 683.5+ KB

# %%
print(df.duplicated().sum())
# Out:
# 126

# %%
# drop duplicated values 
df.drop_duplicates(inplace = True)

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 2          flat                pyramid elite   sector 86   0.46
# 3          flat       breez global hill view  sohna road   0.32
# 4          flat  bestech park view sanskruti   sector 92   1.60
#
#    price_per_sqft     area                                       areaWithType  \
# 0          7585.0   1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8600.0   1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 2            79.0  58228.0                 Carpet area: 58141 (5401.48 sq.m.)
# 3          5470.0    585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 4          8020.0   1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
#
#    bedRoom  bathroom balcony  ...  super_built_up_area built_up_area  \
# 0        3         2       2  ...               1081.0           NaN
# 1        2         2       2  ...                  NaN           NaN
# 2        2         2       1  ...                  NaN           NaN
# 3        2         2       1  ...                  NaN        1000.0
# 4        3         4      3+  ...               1995.0        1615.0
#
#   carpet_area  study room  servant room  store room  pooja room  others room  \
# 0       650.0           0             0           0           0            0
# 1      1103.0           1             1           0           0            0
# 2     58141.0           0             0           0           0            0
# 3       585.0           0             0           0           0            0
# 4      1476.0           0             1           0           0            0
#
#    furnishing_type  luxury_score
# 0                1             8
# 1                1            38
# 2                1            15
# 3                1            49
# 4                2           174
#
# [5 rows x 23 columns]

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# # Univariate analysis

# %% [markdown]
# ## property_type

# %%
df['property_type'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='property_type'>

# %% [markdown]
# #### Observations
# - Flats are in majority (75%) and there are less number of houses (25%)

# %% [markdown]
# ## society

# %%
df['society'].value_counts().shape
# Out:
# (676,)

# %%
df['society'].value_counts()
# Out:
# society
# independent                             486
# tulip violet                             75
# ss the leaf                              73
# shapoorji pallonji joyville gurugram     42
# dlf new town heights                     42
#                                        ...
# rail vihar cghs                           1
# rk tower                                  1
# antriksh green                            1
# imperia elvedor                           1
# m3m golf hills                            1
# Name: count, Length: 676, dtype: int64

# %%
df[df['society'] != 'independent']['society'].value_counts(normalize = True).cumsum().head(80)
# Out:
# society
# tulip violet                            0.023511
# ss the leaf                             0.046395
# shapoorji pallonji joyville gurugram    0.059561
# dlf new town heights                    0.072727
# signature global park                   0.083699
#                                           ...
# central park flower valley              0.509718
# unitech uniworld resorts                0.513480
# adani m2k oyster grande                 0.516928
# raheja vedaanta                         0.520376
# breez global heights                    0.523824
# Name: proportion, Length: 80, dtype: float64

# %%
# make bins of flats absed on appartments
society_counts =  df['society'].value_counts()

freq_bins = {
    "Very High (>100)" : (society_counts > 100).sum(),
    "High (50-100)" : ((society_counts >= 50) & (society_counts <= 100)).sum(),
    "Medium (10-49)" : ((society_counts >= 10) & (society_counts < 50)).sum(),
    "Low (2-9)" : ((society_counts > 1) & (society_counts < 10)).sum(),
    "Very Low (1)" : (society_counts == 1).sum()
}
freq_bins
# Out:
# {'Very High (>100)': np.int64(1),
#  'High (50-100)': np.int64(2),
#  'Medium (10-49)': np.int64(92),
#  'Low (2-9)': np.int64(273),
#  'Very Low (1)': np.int64(308)}

# %%
# top 10 socities
df[df['society'] != 'independent']['society'].value_counts().head(10).plot(kind = 'bar')
# Out:
# <Axes: xlabel='society'>

# %%
print(df['society'].isnull().sum())
# Out:
# 1

# %%
df[df['society'].isnull()]
# Out:
#      property_type society     sector  price  price_per_sqft    area  \
# 2693          flat     NaN  sector 78    0.6          3692.0  1625.0
#
#                             areaWithType  bedRoom  bathroom balcony  ...  \
# 2693  Built Up area: 1625 (150.97 sq.m.)        2         2       0  ...
#
#       super_built_up_area built_up_area carpet_area  study room  servant room  \
# 2693                  NaN        1625.0         NaN           0             0
#
#       store room  pooja room  others room  furnishing_type  luxury_score
# 2693           0           0            0                1             0
#
# [1 rows x 23 columns]

# %% [markdown]
# #### Observations
# - Around 13 % properties comes under independent values.
# - There are 675 societies
# - The top 80 socities have 50 % of the properties and the rest 50 % of the properties comes under the remaining 594 socities.
#      - 'Very High (>100)': Only 1 society has more than 100 listings.
#      - 'High (50-100)': Only 2 societies have between 50 to 100 listings.
#      - 'Medium (10-49)': 92 societies fall in this range with 10 to 49 listings.
#      - 'Low (2-9)': 273 societies have between 2 to 9 listings.
#      - 'Very Low (1)': 308 societies have only 1 listings.
# - 1 missing value

# %% [markdown]
# ## sector

# %%
df['sector'].value_counts().shape
# Out:
# (113,)

# %%
# top 10 sectors
df['sector'].value_counts().head(10).plot(kind = 'bar')
# Out:
# <Axes: xlabel='sector'>

# %%
sector_counts = df['sector'].value_counts()

sector_freq_bins = {
    "Very High (>100)" : (sector_counts > 100).sum(),
    "High (50-100)" : ((sector_counts >= 50) & (sector_counts <= 100)).sum(),
    "Medium (10-49)" : ((sector_counts >= 10) & (sector_counts < 50)).sum(),
    "Low (2-9)" : ((sector_counts > 1) & (sector_counts < 10)).sum(),
    "Very Low (1)" : (sector_counts == 1).sum()
}
sector_freq_bins
# Out:
# {'Very High (>100)': np.int64(3),
#  'High (50-100)': np.int64(25),
#  'Medium (10-49)': np.int64(63),
#  'Low (2-9)': np.int64(21),
#  'Very Low (1)': np.int64(1)}

# %% [markdown]
# #### Observations
#    - There are a total 113 unique sector in the dataset.
#    - Frequency distribution of secotrs:
#        - 'Very High (>100)': Only 3 sector has more than 100 listings.
#        - 'High (50-100)': Only 25 sector have between 50 to 100 listings.
#        - 'Medium (10-49)': 63 sector have between 10 to 49 listings.
#        - 'Low (2-9)': 21 sector have between 2 to 9 listings.
#        - 'Very Low (1)': 1 sector have only 1 listings.

# %% [markdown]
# ## price

# %%
print(df['price'].isnull().sum())
# Out:
# 17

# %%
df['price'].describe()
# Out:
# count    3660.000000
# mean        2.533664
# std         2.980623
# min         0.070000
# 25%         0.950000
# 50%         1.520000
# 75%         2.750000
# max        31.500000
# Name: price, dtype: float64

# %%
sns.histplot(df['price'], kde = True, bins = 50)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.boxplot(x = df['price'], color = 'lightgreen')
plt.grid()

# %%
# skewness and kurtosis
skewness = df['price'].skew()
kurtosis = df['price'].kurt()

print("skewness(rightside) :- ",skewness)
print("kurtosis :- ",kurtosis)
# Out:
# skewness(rightside) :-  3.2791704733134623
# kurtosis :-  14.933372629214258

# %%
# quantile analysis 
quantiles = df['price'].quantile([0.01, 0.05, 0.95, 0.99])
quantiles
# Out:
# 0.01     0.250
# 0.05     0.370
# 0.95     8.500
# 0.99    15.264
# Name: price, dtype: float64

# %% [markdown]
# #### quantiles analysis
#     - 1% properties are price below 0.25 crores.
#     - 5% properties are price below 0.37 crores.
#     - 95% properties are price below 8.50 crores.
#     - 99% properties are price below 15.26 crores.
#
#     - few properties are price above this value

# %%
# identify outliers
Q1 = df['price'].describe()['25%']
Q3 = df['price'].describe()['75%']

IQR = Q3 - Q1

print(IQR)
# Out:
# 1.8

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print("Lower bound :-",lower_bound)
print("Upper bound :-",upper_bound)
# Out:
# Lower bound :- -1.7500000000000002
# Upper bound :- 5.45

# %%
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]
outliers.shape
# Out:
# (425, 23)

# %%
print('In crores :-')
outliers['price'].describe()
# Out:
# In crores :-
# count    425.000000
# mean       9.235624
# std        4.065259
# min        5.460000
# 25%        6.460000
# 50%        8.000000
# 75%       10.750000
# max       31.500000
# Name: price, dtype: float64

# %%
# price binning 
bins = [0, 1, 2, 3, 5, 10, 20, 50]
bins_labels = ["0-1", "1-2", "2-3", "3-5", "5-10", "10-20", "20-50"]
pd.cut(df['price'], bins = bins, labels = bins_labels, right = False).value_counts().sort_index().plot(kind = 'bar')
# Out:
# <Axes: xlabel='price'>

# %%
# ecdf plot (empirical cumulative distribution function)
ecdf = df['price'].value_counts().sort_index().cumsum()/ len(df['price'])
plt.plot(ecdf.index, ecdf, marker = '.', linestyle = 'none')
plt.grid()

# %%
plt.figure(figsize = (15, 6))

plt.subplot(1, 2, 1)
sns.histplot(df['price'], kde = True, bins = 50, color = 'blue')
plt.title("Distribution of Prices (Original)")
plt.xlabel("Price (in crores)")
plt.ylabel("Frequency")

# using log 
plt.subplot(1, 2, 2)
sns.histplot(np.log(df['price']), kde = True, bins = 50, color = 'green')
plt.title("Distribution of Prices (Log transformed)")
plt.xlabel("Price (in crores)")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## price_per_sqft

# %%
print(df['price_per_sqft'].isnull().sum())
# Out:
# 17

# %%
df['price_per_sqft'].describe()
# Out:
# count      3660.000000
# mean      13892.668306
# std       23210.067190
# min           4.000000
# 25%        6817.250000
# 50%        9020.000000
# 75%       13880.500000
# max      600000.000000
# Name: price_per_sqft, dtype: float64

# %%
sns.histplot(df['price_per_sqft'], bins = 50, color = 'blue', kde = True)
# Out:
# <Axes: xlabel='price_per_sqft', ylabel='Count'>

# %%
sns.boxplot(df['price_per_sqft'], color = 'lightgreen')

# %% [markdown]
# #### Observations
# - Potential Outliers
# - Right skewed
# - 17 missing values

# %% [markdown]
# # bedRoom

# %%
print(df['bedRoom'].isnull().sum())
# Out:
# 0

# %%
df['bedRoom'].value_counts().sort_index().plot(kind = 'bar')
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].value_counts(normalize = True).head().plot(kind = 'pie', autopct = '%0.2f%%')
# Out:
# <Axes: ylabel='proportion'>

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 2          flat                pyramid elite   sector 86   0.46
# 3          flat       breez global hill view  sohna road   0.32
# 4          flat  bestech park view sanskruti   sector 92   1.60
#
#    price_per_sqft     area                                       areaWithType  \
# 0          7585.0   1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8600.0   1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 2            79.0  58228.0                 Carpet area: 58141 (5401.48 sq.m.)
# 3          5470.0    585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 4          8020.0   1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
#
#    bedRoom  bathroom balcony  ...  super_built_up_area built_up_area  \
# 0        3         2       2  ...               1081.0           NaN
# 1        2         2       2  ...                  NaN           NaN
# 2        2         2       1  ...                  NaN           NaN
# 3        2         2       1  ...                  NaN        1000.0
# 4        3         4      3+  ...               1995.0        1615.0
#
#   carpet_area  study room  servant room  store room  pooja room  others room  \
# 0       650.0           0             0           0           0            0
# 1      1103.0           1             1           0           0            0
# 2     58141.0           0             0           0           0            0
# 3       585.0           0             0           0           0            0
# 4      1476.0           0             1           0           0            0
#
#    furnishing_type  luxury_score
# 0                1             8
# 1                1            38
# 2                1            15
# 3                1            49
# 4                2           174
#
# [5 rows x 23 columns]

# %% [markdown]
# ## balcony

# %%
print(df['balcony'].isnull().sum())
# Out:
# 0

# %%
df['balcony'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='balcony'>

# %%
df['balcony'].value_counts(normalize = True).head().plot(kind = 'pie', autopct = '%0.2f%%')
# Out:
# <Axes: ylabel='proportion'>

# %% [markdown]
# ## floorNum

# %%
print(df['floorNum'].isnull().sum())
# Out:
# 19

# %%
df['floorNum'].describe()
# Out:
# count    3658.000000
# mean        6.798250
# std         6.012454
# min         0.000000
# 25%         2.000000
# 50%         5.000000
# 75%        10.000000
# max        51.000000
# Name: floorNum, dtype: float64

# %%
df['floorNum'].value_counts().sort_index().plot(kind = 'bar')
# Out:
# <Axes: xlabel='floorNum'>

# %%
sns.boxplot(df['floorNum'], color = 'lightgreen')
# Out:
# <Axes: ylabel='floorNum'>

# %% [markdown]
# ## facing

# %%
print(df['facing'].isnull().sum())
# Out:
# 1045

# %%
# fill the NaN values 
df['facing'].fillna('NA', inplace = True)
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_12664\3214064191.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['facing'].fillna('NA', inplace = True)

# %%
df['facing'].value_counts()
# Out:
# facing
# NA            1045
# North-East     623
# East           623
# North          387
# West           249
# South          231
# North-West     193
# South-East     173
# South-West     153
# Name: count, dtype: int64

# %% [markdown]
# ## agePossession

# %%
print(df['agePossession'].isnull().sum())
# Out:
# 0

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1646
# Undefined              632
# New Property           570
# Moderately Old         563
# Under Construction     266
# Name: count, dtype: int64

# %%
df['agePossession'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='agePossession'>

# %% [markdown]
# ## super_built_up_area

# %%
print(df['super_built_up_area'].isnull().sum())
# Out:
# 1802

# %%
df['super_built_up_area'].describe()
# Out:
# count     1875.000000
# mean      1925.237627
# std        764.172177
# min         89.000000
# 25%       1479.500000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
sns.histplot(df['super_built_up_area'].dropna(), bins = 50, color = 'skyblue', kde = True)
# Out:
# <Axes: xlabel='super_built_up_area', ylabel='Count'>

# %%
sns.boxplot(df['super_built_up_area'].dropna(), color = 'lightgreen')
# Out:
# <Axes: ylabel='super_built_up_area'>

# %% [markdown]
# ## built_up_area

# %%
print(df['built_up_area'].isnull().sum())
# Out:
# 2532

# %%
df['built_up_area'].describe()
# Out:
# count      1145.000000
# mean       2433.853073
# std       21770.086402
# min          30.000000
# 25%        1120.000000
# 50%        1600.000000
# 75%        2060.000000
# max      737147.000000
# Name: built_up_area, dtype: float64

# %%
sns.histplot(df['built_up_area'].dropna(), bins = 50, kde = False)
# Out:
# <Axes: xlabel='built_up_area', ylabel='Count'>

# %%
sns.boxplot(df['built_up_area'].dropna())
# Out:
# <Axes: ylabel='built_up_area'>

# %% [markdown]
# ## carpet_area

# %%
print(df['carpet_area'].isnull().sum())
# Out:
# 1805

# %%
df['carpet_area'].describe()
# Out:
# count      1872.000000
# mean       2529.179507
# std       22799.836449
# min          15.000000
# 25%         843.000000
# 50%        1300.000000
# 75%        1790.000000
# max      607936.000000
# Name: carpet_area, dtype: float64

# %%
sns.histplot(df['carpet_area'].dropna(), bins = 50, kde = False)
# Out:
# <Axes: xlabel='carpet_area', ylabel='Count'>

# %%
sns.boxplot(df['carpet_area'].dropna())
# Out:
# <Axes: ylabel='carpet_area'>

# %% [markdown]
# ## additional rooms

# %%
plt.figure(figsize = (20, 12))

for idx, room in enumerate(['study room', 'servant room', 'store room', 'pooja room', 'others room'], 1):
    ax = plt.subplot(2, 3, idx)
    df[room].value_counts().plot.pie(autopct = '%1.1f%%', startangle = 90, ax = ax)
    plt.title(f'Distribution of {room.title()}')
    plt.ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## furnishing_type

# %%
df['furnishing_type'].value_counts()
# Out:
# furnishing_type
# 1    2436
# 2    1038
# 0     203
# Name: count, dtype: int64

# %%
df['furnishing_type'].value_counts().sort_index().plot(kind = 'pie', autopct = '%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## luxury score

# %%
print(df['luxury_score'].isnull().sum())
# Out:
# 0

# %%
df['luxury_score'].describe()
# Out:
# count    3677.000000
# mean       71.512918
# std        53.059082
# min         0.000000
# 25%        31.000000
# 50%        59.000000
# 75%       110.000000
# max       174.000000
# Name: luxury_score, dtype: float64

# %%
sns.histplot(df['luxury_score'], bins = 50, kde = True)
# Out:
# <Axes: xlabel='luxury_score', ylabel='Count'>

# %%
sns.boxplot(df['luxury_score'])
# Out:
# <Axes: ylabel='luxury_score'>

# %% [markdown]
# # Multivariate analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('Final_gurgaon_properties_cleaned.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 2          flat                pyramid elite   sector 86   0.46
# 3          flat       breez global hill view  sohna road   0.32
# 4          flat  bestech park view sanskruti   sector 92   1.60
#
#    price_per_sqft     area                                       areaWithType  \
# 0          7585.0   1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8600.0   1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 2            79.0  58228.0                 Carpet area: 58141 (5401.48 sq.m.)
# 3          5470.0    585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 4          8020.0   1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# 0        3         2       2       2.0         NaN        New Property
# 1        2         2       2       4.0         NaN        New Property
# 2        2         2       1       0.0         NaN  Under Construction
# 3        2         2       1      17.0         NaN        New Property
# 4        3         4      3+      10.0  North-West      Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               1081.0            NaN        650.0           0             0
# 1                  NaN            NaN       1103.0           1             1
# 2                  NaN            NaN      58141.0           0             0
# 3                  NaN         1000.0        585.0           0             0
# 4               1995.0         1615.0       1476.0           0             1
#
#    store room  pooja room  others room  furnishing_type  luxury_score
# 0           0           0            0                1             8
# 1           0           0            0                1            38
# 2           0           0            0                1            15
# 3           0           0            0                1            49
# 4           0           0            0                2           174

# %% [markdown]
# ## property_type vs price

# %%
sns.barplot(x = df['property_type'], y = df['price'], estimator = np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
sns.boxplot(x = df['property_type'], y = df['price'])
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %% [markdown]
# ## property_type vs area

# %%
sns.barplot(x = df['property_type'], y = df['built_up_area'], estimator = np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
sns.boxplot(x = df['property_type'], y = df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
# remove outlisns from built_up_area column 
df = df[df['built_up_area'] != 737147]

# %%
sns.boxplot(x = df['property_type'], y = df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %% [markdown]
# ## property_type vs price_per_sqft

# %%
sns.barplot(x = df['property_type'], y = df['price_per_sqft'], estimator = np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
sns.boxplot(x = df['property_type'], y = df['price_per_sqft'])
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
# check outliers
df[df['price_per_sqft'] > 100000][['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area', 'areaWithType', 'super_built_up_area', 'built_up_area', 'carpet_area']]
# Out:
#      property_type                      society     sector  price  \
# 229          house                    rk excelo  sector 12   0.60
# 336          house                  independent  sector 28   4.50
# 342          house  unitech nirvana birch court  sector 50   7.10
# 545          house                  independent  sector 24  10.00
# 867          house                   ardee city  sector 52   5.50
# 975          house               uppal southend  sector 49   6.75
# 1027         house                dlf the grove  sector 54   5.70
# 1062         house                  independent  sector 23   2.80
# 1259         house           vipul tatvam villa  sector 48   7.25
# 1385         house     unitech uniworld resorts  sector 33   9.50
# 1628         house         eros rosewood villas  sector 49   2.75
# 1925         house                  independent   sector 4   0.60
# 2004         house                  independent  sector 17   3.50
# 2047         house                        ansal  sector 43   1.85
# 2088         house                  independent  sector 12   3.50
# 2161         house       dlf city plots phase 2  sector 25  10.50
# 2277         house                  independent  sector 55   1.45
# 2418          flat           ambience caitriona  sector 24  14.00
# 2461         house                  independent  sector 12   6.00
# 2738         house            vatika india next  sector 82   7.00
# 2850         house       dlf city plots phase 2  sector 25  10.00
# 3015         house       unitech deerwood chase  sector 50   8.45
# 3046         house       emaar the palm springs  sector 54  24.00
# 3148         house         bhim nagar, sector 6   sector 6   0.85
# 3279         house     unitech uniworld resorts  sector 33  10.00
# 3356         house                  independent  sector 54   3.75
# 3386         house                  independent  sector 38   8.00
# 3449         house                  independent  sector 57   8.00
# 3519         house          huda plot sector 38  sector 38   4.30
#
#       price_per_sqft   area  \
# 229         120000.0   50.0
# 336         125000.0  360.0
# 342         283333.0  251.0
# 545         229885.0  435.0
# 867         183333.0  300.0
# 975         290948.0  232.0
# 1027        211111.0  270.0
# 1062        161849.0  173.0
# 1259        201388.0  360.0
# 1385        173992.0  546.0
# 1628        178571.0  154.0
# 1925        105263.0   57.0
# 2004        218750.0  160.0
# 2047        308333.0   60.0
# 2088        133079.0  263.0
# 2161        261194.0  402.0
# 2277        241666.0   60.0
# 2418        200000.0  700.0
# 2461        315789.0  190.0
# 2738        194444.0  360.0
# 2850        400000.0  250.0
# 3015        235376.0  359.0
# 3046        600000.0  400.0
# 3148        126865.0   67.0
# 3279        181818.0  550.0
# 3356        234375.0  160.0
# 3386        230547.0  347.0
# 3449        266666.0  300.0
# 3519        245398.0  175.0
#
#                                            areaWithType  super_built_up_area  \
# 229   Plot area 50(4.65 sq.m.)Built Up area: 30 sq.f...                  NaN
# 336                    Built Up area: 360 (33.45 sq.m.)                  NaN
# 342                           Plot area 240(22.3 sq.m.)                  NaN
# 545                      Carpet area: 435 (40.41 sq.m.)                  NaN
# 867                          Plot area 300(27.87 sq.m.)                  NaN
# 975                          Plot area 232(21.55 sq.m.)                  NaN
# 1027                   Built Up area: 270 (25.08 sq.m.)                  NaN
# 1062  Plot area 173(16.07 sq.m.)Built Up area: 160 s...                  NaN
# 1259                         Plot area 360(33.45 sq.m.)                  NaN
# 1385                         Plot area 546(50.73 sq.m.)                  NaN
# 1628  Plot area 154(14.31 sq.m.)Carpet area: 1650 sq...                  NaN
# 1925                            Plot area 57(5.3 sq.m.)                  NaN
# 2004                   Built Up area: 160 (14.86 sq.m.)                  NaN
# 2047                           Plot area 60(5.57 sq.m.)                  NaN
# 2088  Plot area 263(24.43 sq.m.)Built Up area: 4800 ...                  NaN
# 2161                         Plot area 402(37.35 sq.m.)                  NaN
# 2277                           Plot area 60(5.57 sq.m.)                  NaN
# 2418                   Built Up area: 700 (65.03 sq.m.)                  NaN
# 2461  Plot area 190(17.65 sq.m.)Carpet area: 1600 sq...                  NaN
# 2738  Plot area 360(33.45 sq.m.)Built Up area: 3900 ...                  NaN
# 2850                         Plot area 250(23.23 sq.m.)                  NaN
# 3015                         Plot area 359(33.35 sq.m.)                  NaN
# 3046                         Plot area 400(37.16 sq.m.)                  NaN
# 3148                           Plot area 67(6.22 sq.m.)                  NaN
# 3279                          Plot area 550(51.1 sq.m.)                  NaN
# 3356                         Plot area 160(14.86 sq.m.)                  NaN
# 3386  Built Up area: 347 (32.24 sq.m.)Carpet area: 2...                  NaN
# 3449                         Plot area 300(27.87 sq.m.)                  NaN
# 3519  Plot area 163(15.14 sq.m.)Built Up area: 145 s...                  NaN
#
#       built_up_area  carpet_area
# 229            30.0         15.0
# 336           360.0          NaN
# 342             NaN          NaN
# 545             NaN        435.0
# 867             NaN          NaN
# 975             NaN          NaN
# 1027          270.0          NaN
# 1062          160.0        150.0
# 1259            NaN          NaN
# 1385            NaN          NaN
# 1628            NaN       1650.0
# 1925            NaN          NaN
# 2004          160.0          NaN
# 2047            NaN          NaN
# 2088         4800.0       4400.0
# 2161            NaN          NaN
# 2277            NaN          NaN
# 2418          700.0          NaN
# 2461            NaN       1600.0
# 2738         3900.0       3743.0
# 2850            NaN          NaN
# 3015            NaN          NaN
# 3046            NaN          NaN
# 3148            NaN          NaN
# 3279            NaN          NaN
# 3356            NaN          NaN
# 3386          347.0        215.0
# 3449            NaN          NaN
# 3519          145.0          NaN

# %%
sns.heatmap(pd.crosstab(df['property_type'], df['bedRoom']))
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
# check outliers
df[df['bedRoom'] >= 10]
# Out:
#      property_type                    society      sector  price  \
# 19           house                independent   sector 54   5.50
# 48           house  ganpati heights apartment   sector 13   1.25
# 66           house                independent   sector 13   0.50
# 78           house                independent  sector 17a   3.87
# 119          house                independent   sector 55   7.49
# ...            ...                        ...         ...    ...
# 3479         house                independent   sector 25    NaN
# 3519         house        huda plot sector 38   sector 38   4.30
# 3618         house                independent   sector 54   5.00
# 3698         house                independent   sector 55   9.19
# 3713         house                independent   sector 41   4.25
#
#       price_per_sqft     area  \
# 19           38194.0   1440.0
# 48             151.0  82781.0
# 66           90909.0     55.0
# 78            5160.0   7500.0
# 119          27741.0   2700.0
# ...              ...      ...
# 3479             NaN      NaN
# 3519        245398.0    175.0
# 3618         43066.0   1161.0
# 3698         34037.0   2700.0
# 3713         26235.0   1620.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 19                          Plot area 160(133.78 sq.m.)       18        18
# 48                         Plot area 115(7692.86 sq.m.)       10         6
# 66                             Plot area 55(5.11 sq.m.)       12         4
# 78    Plot area 1623(150.78 sq.m.)Built Up area: 750...       19        17
# 119                         Plot area 300(250.84 sq.m.)       12        12
# ...                                                 ...      ...       ...
# 3479  Plot area 250(209.03 sq.m.)Built Up area: 260 ...       12        12
# 3519  Plot area 163(15.14 sq.m.)Built Up area: 145 s...       13        13
# 3618                        Plot area 129(107.86 sq.m.)       21        21
# 3698                        Plot area 300(250.84 sq.m.)       16        18
# 3713                         Plot area 180(150.5 sq.m.)       10         9
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 19        3+       4.0  South-West  Relatively New                  NaN
# 48         2       3.0  South-East       Undefined                  NaN
# 66         3       4.0         NaN       Undefined                  NaN
# 78        3+       5.0  North-West  Relatively New                  NaN
# 119       3+       4.0  South-East  Relatively New                  NaN
# ...      ...       ...         ...             ...                  ...
# 3479      3+       4.0  North-East    New Property                  NaN
# 3519      3+       5.0  North-West  Relatively New                  NaN
# 3618      3+       5.0       North  Relatively New                  NaN
# 3698       2       4.0        West    New Property                  NaN
# 3713      3+       4.0       North  Moderately Old                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 19              NaN          NaN           0             1           0
# 48              NaN          NaN           0             0           0
# 66              NaN          NaN           0             0           0
# 78           7500.0          NaN           1             0           1
# 119             NaN          NaN           1             1           0
# ...             ...          ...         ...           ...         ...
# 3479          260.0        245.0           1             1           0
# 3519          145.0          NaN           0             0           0
# 3618            NaN          NaN           0             1           0
# 3698            NaN          NaN           0             1           0
# 3713            NaN          NaN           1             1           0
#
#       pooja room  others room  furnishing_type  luxury_score
# 19             0            0                0            70
# 48             0            0                1             7
# 66             0            0                1            15
# 78             0            0                1            68
# 119            1            0                2            49
# ...          ...          ...              ...           ...
# 3479           1            0                0           144
# 3519           0            0                0             7
# 3618           0            0                0            49
# 3698           1            0                2            49
# 3713           0            0                2            36
#
# [72 rows x 23 columns]

# %% [markdown]
# ## property_type vs floorNum

# %%
sns.barplot(x = df['property_type'], y = df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
sns.boxplot(x = df['property_type'], y = df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
# check outliers
df[(df['property_type'] == 'house') & (df['floorNum'] > 10)]
# Out:
#      property_type                  society      sector  price  \
# 35           house              greenopolis   sector 89   0.70
# 106          house        suncity avenue 76   sector 76   0.75
# 267          house               ninex city   sector 76   1.75
# 338          house              spaze privy   sector 72   3.09
# 420          house              spaze privy   sector 72   3.10
# 1297         house  indiabulls centrum park  sector 103   3.25
# 2147         house      ireo victory valley   sector 67   8.00
# 2167         house         suncity township   sector 54   2.00
# 2556         house           dlf the arbour   sector 63   8.50
# 2796         house              independent   sector 92   1.80
# 2969         house      satya the hermitage  sector 103   3.15
# 2973         house          godrej meridien  sector 106   5.60
# 3224         house   vatika the seven lamps   sector 82   1.60
# 3668         house           ats tourmaline  sector 109   1.87
#
#       price_per_sqft    area  \
# 35            5397.0  1297.0
# 106          10067.0   745.0
# 267           6250.0  2800.0
# 338           6981.0  4426.0
# 420           8486.0  3653.0
# 1297          8125.0  4000.0
# 2147         22222.0  3600.0
# 2167         30968.0   646.0
# 2556         21519.0  3950.0
# 2796          7627.0  2360.0
# 2969          6702.0  4700.0
# 2973         14000.0  4000.0
# 3224          6597.0  2425.0
# 3668          8697.0  2150.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 35                    Built Up area: 1297 (120.5 sq.m.)        2         2
# 106   Plot area 745(69.21 sq.m.)Built Up area: 745 s...        2         2
# 267                    Carpet area: 2800 (260.13 sq.m.)        4         4
# 338   Built Up area: 3653 (339.37 sq.m.)Carpet area:...        5         5
# 420                        Plot area 3653(339.37 sq.m.)        5         5
# 1297                       Plot area 4000(371.61 sq.m.)        4         3
# 2147                        Plot area 400(334.45 sq.m.)        6         7
# 2167  Plot area 60Built Up area: 60 sq.m.Carpet area...        9         9
# 2556                 Built Up area: 3950 (366.97 sq.m.)        4         4
# 2796                 Built Up area: 2360 (219.25 sq.m.)        4         5
# 2969                 Built Up area: 4700 (436.64 sq.m.)        4         5
# 2973                       Plot area 4000(371.61 sq.m.)        5         4
# 3224                       Plot area 2425(225.29 sq.m.)        4         4
# 3668                 Built Up area: 2150 (199.74 sq.m.)        3         4
#
#      balcony  floorNum      facing       agePossession  super_built_up_area  \
# 35         2      14.0  North-East           Undefined                  NaN
# 106        2      11.0  North-East        New Property                  NaN
# 267        0      14.0         NaN           Undefined                  NaN
# 338       3+      14.0        East      Relatively New                  NaN
# 420       3+      21.0         NaN      Relatively New                  NaN
# 1297      3+      20.0         NaN  Under Construction                  NaN
# 2147      3+      51.0  North-East      Moderately Old                  NaN
# 2167       3      11.0       North      Relatively New                  NaN
# 2556      3+      27.0         NaN           Undefined                  NaN
# 2796       0      13.0         NaN           Undefined                  NaN
# 2969       0      12.0        East           Undefined                  NaN
# 2973      3+      33.0  North-East        New Property                  NaN
# 3224      3+      16.0       North      Moderately Old                  NaN
# 3668       0      12.0         NaN           Undefined                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 35           1297.0          NaN           0             0           0
# 106           745.0          NaN           0             0           0
# 267             NaN       2800.0           0             0           0
# 338          3653.0       2922.0           0             1           0
# 420             NaN          NaN           0             0           0
# 1297            NaN          NaN           0             0           0
# 2147            NaN          NaN           1             1           0
# 2167           60.0         59.0           0             1           0
# 2556         3950.0          NaN           0             0           0
# 2796         2360.0          NaN           0             0           0
# 2969         4700.0          NaN           0             0           0
# 2973            NaN          NaN           1             1           1
# 3224            NaN          NaN           0             1           0
# 3668         2150.0          NaN           0             0           0
#
#       pooja room  others room  furnishing_type  luxury_score
# 35             0            0                1             0
# 106            0            0                1            40
# 267            0            0                1             0
# 338            0            0                2            33
# 420            0            0                1             0
# 1297           0            0                1            51
# 2147           1            0                2            49
# 2167           0            0                0             7
# 2556           0            0                1            61
# 2796           0            0                1             0
# 2969           0            0                1            61
# 2973           1            0                1           151
# 3224           0            0                1            94
# 3668           0            0                1             0

# %%
sns.heatmap(pd.crosstab(df['property_type'], df['agePossession']))
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df, index = 'property_type', columns = 'agePossession', values = 'price', aggfunc = 'mean'), annot = True)
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
sns.heatmap(pd.crosstab(df['property_type'], df['furnishing_type']))
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
 sns.heatmap(pd.pivot_table(df, index = 'property_type', columns = 'furnishing_type', values = 'price', aggfunc = 'mean'), annot = True)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.barplot(x = df['property_type'], y = df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
sns.boxplot(x = df['property_type'], y = df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
# sector analysis 
plt.figure(figsize = (15,6))

sns.heatmap(pd.crosstab(df['property_type'], df['sector'].sort_index()))
# Out:
# <Axes: xlabel='sector', ylabel='property_type'>

# %%
import re

avg_price_per_sector = df.groupby('sector')['price'].mean().reset_index()

def extract_sector_number(sector_name):
    match = re.search(r'\d+', sector_name)
    if match:
        return int(match.group())
    else:
        return float('inf')

avg_price_per_sector['sector_number'] = avg_price_per_sector['sector'].apply(extract_sector_number)

avg_price_per_sector_sorted_by_sector = avg_price_per_sector.sort_values(by = 'sector_number')

plt.figure(figsize = (5, 25))

sns.heatmap(avg_price_per_sector_sorted_by_sector.set_index('sector')[['price']], annot = True, fmt = ".2f", linewidth = 5)

plt.title('Average price per sector (sorted by sector number)')
plt.xlabel('Average price')
plt.ylabel('Sector')
plt.show()

# %%
avg_price_per_sqft_sector = df.groupby('sector')['price_per_sqft'].mean().reset_index()

avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)

avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by = 'sector_number')

plt.figure(figsize = (5, 25))

sns.heatmap(avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['price_per_sqft']], annot = True, fmt = ".2f", linewidth = 5)

plt.title('Sector (sorted by sector number)')
plt.xlabel('Average price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
luxury_score = df.groupby('sector')['luxury_score'].mean().reset_index()

luxury_score['sector_number'] = luxury_score['sector'].apply(extract_sector_number)

luxury_score_sector = luxury_score.sort_values(by = 'sector_number')

plt.figure(figsize = (5, 25))

sns.heatmap(luxury_score_sector.set_index('sector')[['luxury_score']], annot = True, fmt = ".2f", linewidth = 5)

plt.title('Sector (sorted by sector number)')
plt.xlabel('Average price per sqft')
plt.ylabel('Sector')
plt.show()

# %% [markdown]
# ## price

# %%
plt.figure(figsize = (12, 8))
sns.scatterplot(x = df[df['area'] < 10000]['area'], y = df['price'], hue = df['bedRoom'])
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
plt.figure(figsize = (12, 8))
sns.scatterplot(x = df[df['area'] < 10000]['area'], y = df['price'], hue = df['agePossession'])
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
plt.figure(figsize = (12, 8))
sns.scatterplot(x = df[df['area'] < 10000]['area'], y = df['price'], hue = df['furnishing_type'].astype('category'))
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
sns.barplot(x = df['bedRoom'], y = df['price'], estimator = np.median)
# Out:
# <Axes: xlabel='bedRoom', ylabel='price'>

# %%
sns.barplot(x = df['agePossession'], y = df['price'], estimator = np.median)
plt.xticks(rotation = 'vertical')
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'New Property'),
#   Text(1, 0, 'Under Construction'),
#   Text(2, 0, 'Relatively New'),
#   Text(3, 0, 'Undefined'),
#   Text(4, 0, 'Moderately Old')])

# %%
sns.barplot(x = df['agePossession'], y = df['area'], estimator = np.median)
plt.xticks(rotation = 'vertical')
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'New Property'),
#   Text(1, 0, 'Under Construction'),
#   Text(2, 0, 'Relatively New'),
#   Text(3, 0, 'Undefined'),
#   Text(4, 0, 'Moderately Old')])

# %%
sns.barplot(x = df['furnishing_type'], y = df['price'], estimator = np.median)
plt.xticks(rotation = 'vertical')
# Out:
# ([0, 1, 2], [Text(0, 0, '0'), Text(1, 0, '1'), Text(2, 0, '2')])

# %%
sns.scatterplot(x = df['luxury_score'], y = df['price'])
# Out:
# <Axes: xlabel='luxury_score', ylabel='price'>

# %% [markdown]
# ## correlation

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])
plt.figure(figsize = (8,8))
sns.heatmap(numeric_df.corr())
# Out:
# <Axes: >

# %%
numeric_df.corr()['price'].sort_values(ascending = False)
# Out:
# price                  1.000000
# super_built_up_area    0.769412
# bathroom               0.589826
# bedRoom                0.522925
# built_up_area          0.497228
# servant room           0.400927
# price_per_sqft         0.391251
# pooja room             0.341492
# store room             0.309121
# study room             0.258602
# furnishing_type        0.133418
# luxury_score           0.094775
# area                   0.034720
# carpet_area           -0.011344
# floorNum              -0.094290
# others room                 NaN
# Name: price, dtype: float64
